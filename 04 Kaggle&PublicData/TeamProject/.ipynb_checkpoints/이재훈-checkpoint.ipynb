# %% [markdown]
# ## 지출 목적별 소비자 물가 지수
# ##### 19년도 1월 부터 22년 6월까지 항목별 소비자 물가 지수
# ##### 그 중 교통, 통신, 오락, 교육, 음식 및 숙박, 기타 상품 및 서비스에 대해서 조사

# %%
import pandas as pd

# %%
price_Data = pd.read_excel('./Data/지출목적별_소비자물가지수_품목포함__2020100__20220720090824.xls', index_col = 1).drop('시도별',axis = 1).T
price_Data = price_Data.rename(columns = {'07 교통':'교통', '08 통신':'통신', '09 오락 및 문화':'오락', '10 교육' : '교육',
                                         '11 음식 및 숙박' : '음식 숙박', '12 기타 상품 및 서비스': '기타 상품 및 서비스'})
price_Data.index = pd.period_range('2019-01-01','2022-06-30',freq = 'm')

# %%
price_Data
# Out:
# 지출목적별         교통       통신       오락       교육    음식 숙박  기타 상품 및 서비스
# 2019-01   98.899  103.283  100.468  102.456   98.699       97.357
# 2019-02   98.699  102.390  101.319  102.563   98.870       97.664
# 2019-03   99.289  102.127  100.587  102.602   98.636       97.836
# 2019-04  100.769  102.411  101.615  102.660   98.789       98.052
# 2019-05  103.049  102.201  101.200  102.748   98.978       98.395
# 2019-06  103.299  102.043  100.181  102.797   99.068       98.152
# 2019-07  102.569  101.613  101.685  102.797   99.284       98.224
# 2019-08  102.579  102.001  102.515  102.826   99.545       98.188
# 2019-09  102.979  102.285  101.418  101.031   99.050       98.188
# 2019-10  103.589  102.211  101.774  101.168   99.212       98.260
# 2019-11  103.109  101.413  100.092  101.217   99.230       98.323
# 2019-12  103.569  101.361   99.420  101.275   99.374       98.341
# 2020-01  105.090  100.750  100.120   99.860   99.720       99.400
# 2020-02  105.060  100.700   99.830  100.040   99.650       99.740
# 2020-03  101.880  100.660   99.400  100.030   99.500       99.660
# 2020-04   98.280  101.290   99.710  100.060   99.580       99.440
# 2020-05   96.060  101.250  100.020   99.970   99.790       99.840
# 2020-06   97.630  101.840   99.840  100.010   99.880       99.970
# 2020-07   99.620  101.760  100.230  100.080  100.120      100.210
# 2020-08   99.830  101.690  100.690  100.170  100.390      100.110
# 2020-09   99.400  101.620  100.030   99.870  100.210      100.870
# 2020-10   99.050   87.780  100.330   99.900  100.430      100.160
# 2020-11   98.590   99.890   99.920   99.970  100.230      100.400
# 2020-12   99.510  100.750   99.890  100.030  100.510      100.200
# 2021-01  101.820   99.220  100.130  100.250  100.790      101.410
# 2021-02  102.550   99.250  100.030  100.390  101.060      101.310
# 2021-03  103.970   99.320   99.820  100.770  101.420      101.550
# 2021-04  104.710   99.320  100.400  100.890  101.940      102.140
# 2021-05  104.660   98.880  100.530  100.890  102.130      102.310
# 2021-06  105.530   98.870   99.890  100.950  102.320      102.000
# 2021-07  107.070   98.870  100.720  101.000  102.900      102.080
# 2021-08  107.900   98.880  101.210  101.100  103.390      102.300
# 2021-09  107.590   98.890  100.630  100.940  103.440      102.100
# 2021-10  109.310   98.390  100.650  101.040  103.820      102.230
# 2021-11  111.480   99.620  100.380  101.050  104.280      101.800
# 2021-12  109.410   99.630  100.810  101.150  105.260      102.810
# 2022-01  109.110   99.640  101.740  101.430  106.260      104.860
# 2022-02  111.040   99.640  101.530  101.590  107.150      106.100
# 2022-03  117.160   99.500  102.070  101.740  107.970      106.060
# 2022-04  119.200   99.790  102.560  101.950  108.540      105.930
# 2022-05  119.790   99.800  102.680  102.090  109.550      107.780
# 2022-06  123.310   99.820  103.240  102.410  110.380      108.620

# %% [markdown]
# ##### 코로나 확진자 수 자료

# %%
covid19 = pd.read_excel('./Data/코로나바이러스감염증-19_확진환자_발생현황.xlsx', skiprows=4).drop(0)
covid19 = covid19.iloc[:,[0,1]].rename(columns = {'계(명)': '확진자 수'})
covid19['일자'] = pd.to_datetime(covid19['일자'])
covid19.set_index('일자', inplace = True)
covid19 = covid19.to_period('m')
covid19 = covid19.reset_index().groupby('일자').sum()
covid19 = covid19.drop('2022-07')

# %% [markdown]
# ##### 원유 가격 변동 자료

# %%
oilPrice = pd.read_csv('./Data/원유가격현황.csv')
oilPrice = oilPrice[['날짜', '종가']]
oilPrice['날짜'] = pd.to_datetime(oilPrice['날짜'], format = '%Y년 %m월 %d일')
oilPrice = oilPrice.set_index('날짜').to_period('m').reset_index().groupby('날짜').mean()
oilPrice.columns = ['원유 종가']

# %% [markdown]
# ##### 한국 금리변동 자료

# %%
interestRate = pd.read_csv('./Data/국제 주요국 중앙은행 정책금리_19141249.csv', encoding = 'euc-kr', index_col = 1).iloc[:,3:].T
ys = ['2019']*12 +['2020']*12 +['2021']*12 + ['2022']*6
interestRate.index = [ys[i] +' '+ interestRate.index[i] for i in range(len(ys))]
interestRate.index = pd.to_datetime(interestRate.index, format = '%Y %b-%d')
interestRate = interestRate.to_period('m')[['한국']]
interestRate.columns = ['한국 금리']
interestRate = interestRate.fillna(2.25)

# %% [markdown]
# ##### 자료 통합 및 정규화

# %%
df_total = pd.concat([price_Data, covid19, oilPrice, interestRate], axis = 1, ).fillna(0)
def get_range(s):
    return [s.max(), s.min(), s.max() - s.min()]
df_total.apply(get_range)

import numpy as np
df_total = df_total.copy()
df_total['확진자 수'] = df_total['확진자 수'].apply(lambda x : np.log10(x+1))

def min_max_scal(x):
    return((x-x.min())/(x.max()-x.min()))

df_total_01 = df_total.apply(min_max_scal)

# %% [markdown]
# ##### 시각화

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import platform
from datetime import datetime
if platform.system() == 'Windows':
    plt.rc('font', family='Malgun Gothic')
else:
    plt.rc('font', family='AppleGothic')

# %% [markdown]
# ## 종목이 다양하기 때문에 우선은 상관계수가 높은 종목을 구분

# %% [markdown]
# ### 각 요소 간의 상관관계 분석

# %%
plt.figure(figsize=(16,16))
plt.rcParams['axes.unicode_minus'] = False
sns.heatmap(df_total_01.corr(), annot= True, cmap='RdBu_r', annot_kws={'size':20}, linewidth = 2)
plt.title('변수들간의 상관관계 히트맵', pad = 20, position=(0.5, -5), fontdict={'fontsize': 22, 'fontweight': 'bold'})
plt.rc('xtick', labelsize=18)
plt.rc('ytick', labelsize=18)

# %% [markdown]
# #### 상관관계를 분석해본 결과
# #### 통신 비용은 확진자 수, 원유 종가, 한국 금리 모든 변수와 상관계수가 0.5가 넘지 않는 것을 알 수 있습니다.
# #### 통신비용의 경우 우편료나 휴대전화비 등 한번 정해지면 변동폭이 크지 않은 비용들이라 상관관계가 약한 것으로 보입니다.
# #### 통신을 제외한 다른 종목들을 그래프로 그려 분석해보겠습니다

# %%
colors = sns.color_palette('tab10', 10)
lf_cols = list(df_total_01.columns[:6])
fac_cols = list(df_total_01.columns[6:])

def draw_scaled(df_total_01, col = ' ', time = ' '):
    print('\n\n')
    plt.figure(figsize=(16,6))
    plt.rc('xtick', labelsize=13)
    plt.rc('ytick', labelsize=13)
    plt.bar(range(len(df_total_01.index)), df_total_01[col], alpha = 0.5, color = colors[0])
    plt.xticks(range(len(df_total_01.index)), df_total_01.index, rotation=80)
    for fac in fac_cols:
        plt.plot(range(len(df_total_01.index)),df_total_01[fac],
                 linestyle = '--', marker = 's', color = colors[fac_cols.index(fac)+1])
    legs = list(df_total_01.columns[6:]) +[col] 

    plt.legend(legs,loc = 2)
    
    if time == '코로나':
        plt.axvspan(11, 15, facecolor='orange', alpha=0.3)
        plt.text(x=16.5, y = 0.93, s = '코로나 확산 초기 ', fontsize = 14, color = 'black', ha = 'right' )
    elif time == '우-러 전쟁 반발':
        plt.axvline(x=37, ymin=0, ymax=1.0, color = 'black', alpha = 0.5)
        plt.text(x=26, y = 0.93, s = '우-러 전쟁 발발 ', fontsize = 14, color = 'black', ha = 'right' )
        plt.axhline(y=0.425, xmin=0, xmax=1.0, color = 'red', alpha = 0.5, linestyle='--')
        plt.text(x=8, y = 0.5, s = '코로나 이전 원유 종가 및 금리', fontsize = 14, color = 'r',  ha = 'right' )
    elif time == '최근':
        plt.axvspan(38, 41, facecolor='red', alpha=0.3)
        plt.text(x=43.5, y = 0.2, s = '코로나 확산 감소 ', fontsize = 14, color = 'black', ha = 'right' )
    
    plt.title(f'{col}과(와) 변수들간의 그래프', pad = 20, position=(0.5, -5), fontdict={'fontsize': 16, 'fontweight': 'bold'})
    plt.show()
    print('\n\n')

# %%
def showgraph(var= ' '):
    for col in lf_cols:
        if col == '통신':
            continue
        else:
            draw_scaled(df_total_01, col, var)

# %%
showgraph('코로나')

# %% [markdown]
# #### 그래프를 통해서 2019년 12월부터 코로나 확진자 수가 증가하기 시작하면서
#
# #### 5개월간 원유 가격과 금리가 급격히 하락하는 것을 알 수 있습니다.
#
# #### 전세계적인 코로나 확산으로 인한 대봉쇄의 영향으로, 전 지구적인 경제 침체의 영향으로 인한 결과임을 유추할 수 있으며
#
# #### 교통과 오락, 교육의 경우 이에 영향을 받아 그래프가 급격히 낮아짐을 알 수 있습니다.
#
# #### 반면 음식 숙박, 기타 상품 및 서비스의 경우 그 영향력이 미비하거나 더 올라감을 알 수 있습니다.

# %%
showgraph('우-러 전쟁 반발')

# %% [markdown]
# #### 이후 금리는 코로나 영향으로 2021년 7월까지 동결되었지만 원유 가격은 저점을 찍은 후 증가함을 알 수 있습니다.
# #### 2021년 2월 이미 원유 종가는 코로나 이전보다 높아졌으며
# #### 특히 2022년 2월 우크라이나-러시아 전쟁이 반발하기 두달 전부터
# #### 원유 종가가 가파르게  증가하고 있습니다.
# #### 22년 1월부터 동결되었던 한국의 금리 수치가 코로나 이전으로 복귀하였고
# #### 원유 종가의 가격이 코로나 이전보다 월등히 증가하면서 모든 종목에서 소비자 물가가 상승함을 알 수 있다

# %%
showgraph('최근')

# %% [markdown]
# #### 2022년 3월 이후로는 코로나 확진자 수 추세가 꺽였음에도 소비자 물가는 계속 상승함을 볼 수 있다
# #### 따라서 코로나 확산세 초기의 상황과 달리 현재의 소비자 물가에 영향을 미치는 요인은
# #### 우크라이나 - 러시아 간의 전쟁이나 금리 조정 등이 주가 되었고
# #### 코로나 확산이란 변수의 영향력이 크게 감소했음을 알 수 있다.

# %%
fh_Data = pd.read_csv('./Data/음식 숙박 데이터.csv', encoding='euc_kr', index_col = 1).drop('시도별',axis = 1).T
fh_Data.index = pd.period_range('2019-01-01','2022-06-30',freq = 'm')

# %%
fh_Data
# Out:
# 지출목적별     음식 서비스   숙박 서비스
# 2019-01   98.891   94.514
# 2019-02   99.071   94.174
# 2019-03   98.891   92.611
# 2019-04   99.062   92.548
# 2019-05   99.197   93.763
# 2019-06   99.314   93.522
# 2019-07   99.377   97.034
# 2019-08   99.449  101.733
# 2019-09   99.179   95.997
# 2019-10   99.359   95.720
# 2019-11   99.395   95.363
# 2019-12   99.485   96.864
# 2020-01   99.630  102.360
# 2020-02   99.670   99.230
# 2020-03   99.620   96.050
# 2020-04   99.690   96.500
# 2020-05   99.840   98.510
# 2020-06   99.950   97.840
# 2020-07   99.980  103.730
# 2020-08  100.020  110.720
# 2020-09  100.260   98.880
# 2020-10  100.470   99.280
# 2020-11  100.340   97.390
# 2020-12  100.540   99.510
# 2021-01  100.900   97.790
# 2021-02  101.160   98.230
# 2021-03  101.640   95.500
# 2021-04  102.120   96.950
# 2021-05  102.260   98.500
# 2021-06  102.500   97.440
# 2021-07  102.780  106.120
# 2021-08  103.090  111.690
# 2021-09  103.510  101.370
# 2021-10  103.910  101.350
# 2021-11  104.480   98.760
# 2021-12  105.380  101.830
# 2022-01  106.400  102.270
# 2022-02  107.390  100.430
# 2022-03  108.340   97.980
# 2022-04  108.850  100.000
# 2022-05  109.810  102.450
# 2022-06  110.670  102.350

# %%
fh_total = pd.concat([fh_Data, covid19, oilPrice, interestRate], axis = 1, ).fillna(0)
fh_total
# Out:
#           음식 서비스   숙박 서비스      확진자 수       원유 종가  한국 금리
# 2019-01   98.891   94.514        0.0   51.514167   1.75
# 2019-02   99.071   94.174        0.0   55.106190   1.75
# 2019-03   98.891   92.611        0.0   58.168095   1.75
# 2019-04   99.062   92.548        0.0   63.870952   1.75
# 2019-05   99.197   93.763        0.0   60.707083   1.75
# 2019-06   99.314   93.522        0.0   54.706500   1.75
# 2019-07   99.377   97.034        0.0   57.513913   1.50
# 2019-08   99.449  101.733        0.0   54.844091   1.50
# 2019-09   99.179   95.997        0.0   56.763636   1.50
# 2019-10   99.359   95.720        0.0   54.005652   1.25
# 2019-11   99.395   95.363        0.0   57.118095   1.25
# 2019-12   99.485   96.864        0.0   59.867727   1.25
# 2020-01   99.630  102.360       11.0   57.809583   1.25
# 2020-02   99.670   99.230     2920.0   50.707619   1.25
# 2020-03   99.620   96.050     6855.0   30.445455   0.75
# 2020-04   99.690   96.500      979.0   16.699048   0.75
# 2020-05   99.840   98.510      703.0   28.971364   0.50
# 2020-06   99.950   97.840     1331.0   38.313636   0.50
# 2020-07   99.980  103.730     1506.0   40.744783   0.50
# 2020-08  100.020  110.720     5641.0   42.388095   0.50
# 2020-09  100.260   98.880     3865.0   39.569130   0.50
# 2020-10  100.470   99.280     2700.0   39.554545   0.50
# 2020-11  100.340   97.390     7688.0   41.519524   0.50
# 2020-12  100.540   99.510    26527.0   47.068182   0.50
# 2021-01  100.900   97.790    17471.0   52.119048   0.50
# 2021-02  101.160   98.230    11467.0   59.172381   0.50
# 2021-03  101.640   95.500    13415.0   62.357391   0.50
# 2021-04  102.120   96.950    18927.0   61.703810   0.50
# 2021-05  102.260   98.500    18331.0   65.304091   0.50
# 2021-06  102.500   97.440    16623.0   71.352727   0.50
# 2021-07  102.780  106.120    41374.0   72.714348   0.50
# 2021-08  103.090  111.690    53077.0   67.711364   0.75
# 2021-09  103.510  101.370    59857.0   71.303913   0.75
# 2021-10  103.910  101.350    53415.0   81.222857   0.75
# 2021-11  104.480   98.760    82517.0   78.597273   1.00
# 2021-12  105.380  101.830   183596.0   71.690000   1.00
# 2022-01  106.400  102.270   214819.0   83.050000   1.25
# 2022-02  107.390  100.430  2288500.0   91.677143   1.25
# 2022-03  108.340   97.980  9960544.0  108.262174   1.25
# 2022-04  108.850  100.000  4142605.0  101.640500   1.50
# 2022-05  109.810  102.450   866081.0  109.898696   1.75
# 2022-06  110.670  102.350   255909.0  113.865217   2.25

# %%
fh_total.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# PeriodIndex: 42 entries, 2019-01 to 2022-06
# Freq: M
# Data columns (total 5 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   음식 서비스  42 non-null     float64
#  1   숙박 서비스  42 non-null     float64
#  2   확진자 수   42 non-null     float64
#  3   원유 종가   42 non-null     float64
#  4   한국 금리   42 non-null     float64
# dtypes: float64(5)
# memory usage: 2.0 KB

# %%
fh_total_01 = fh_total.apply(min_max_scal)
fh_total_01
# Out:
#            음식 서비스    숙박 서비스     확진자 수     원유 종가     한국 금리
# 2019-01  0.000000  0.102706  0.000000  0.358305  0.714286
# 2019-02  0.015281  0.084944  0.000000  0.395273  0.714286
# 2019-03  0.000000  0.003291  0.000000  0.426785  0.714286
# 2019-04  0.014517  0.000000  0.000000  0.485477  0.714286
# 2019-05  0.025978  0.063473  0.000000  0.452915  0.714286
# 2019-06  0.035911  0.050883  0.000000  0.391159  0.714286
# 2019-07  0.041260  0.234354  0.000000  0.420052  0.571429
# 2019-08  0.047372  0.479835  0.000000  0.392575  0.571429
# 2019-09  0.024450  0.180180  0.000000  0.412331  0.571429
# 2019-10  0.039732  0.165709  0.000000  0.383946  0.428571
# 2019-11  0.042788  0.147059  0.000000  0.415979  0.428571
# 2019-12  0.050429  0.225473  0.000000  0.444277  0.428571
# 2020-01  0.062739  0.512590  0.000001  0.423095  0.428571
# 2020-02  0.066135  0.349075  0.000293  0.350004  0.428571
# 2020-03  0.061890  0.182948  0.000688  0.141473  0.142857
# 2020-04  0.067833  0.206457  0.000098  0.000000  0.142857
# 2020-05  0.080567  0.311462  0.000071  0.126302  0.000000
# 2020-06  0.089906  0.276460  0.000134  0.222450  0.000000
# 2020-07  0.092453  0.584160  0.000151  0.247470  0.000000
# 2020-08  0.095849  0.949326  0.000566  0.264383  0.000000
# 2020-09  0.116224  0.330791  0.000388  0.235371  0.000000
# 2020-10  0.134052  0.351687  0.000271  0.235221  0.000000
# 2020-11  0.123016  0.252952  0.000772  0.255444  0.000000
# 2020-12  0.139995  0.363703  0.002663  0.312548  0.000000
# 2021-01  0.170558  0.273848  0.001754  0.364530  0.000000
# 2021-02  0.192631  0.296834  0.001151  0.437121  0.000000
# 2021-03  0.233381  0.154216  0.001347  0.469900  0.000000
# 2021-04  0.274132  0.229966  0.001900  0.463173  0.000000
# 2021-05  0.286017  0.310939  0.001840  0.500226  0.000000
# 2021-06  0.306393  0.255564  0.001669  0.562476  0.000000
# 2021-07  0.330164  0.709017  0.004154  0.576490  0.000000
# 2021-08  0.356482  1.000000  0.005329  0.525001  0.142857
# 2021-09  0.392139  0.460871  0.006009  0.561974  0.142857
# 2021-10  0.426097  0.459827  0.005363  0.664056  0.142857
# 2021-11  0.474488  0.324522  0.008284  0.637035  0.285714
# 2021-12  0.550896  0.484902  0.018432  0.565948  0.285714
# 2022-01  0.637490  0.507888  0.021567  0.682861  0.428571
# 2022-02  0.721538  0.411765  0.229757  0.771648  0.428571
# 2022-03  0.802190  0.283774  1.000000  0.942335  0.428571
# 2022-04  0.845488  0.389301  0.415901  0.874188  0.571429
# 2022-05  0.926989  0.517292  0.086951  0.959178  0.714286
# 2022-06  1.000000  0.512068  0.025692  1.000000  1.000000

# %%
plt.plot(fh_total_01)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Input In [19], in <cell line: 1>()
# ----> 1 plt.plot(fh_total_01)
#
# File C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\pyplot.py:2757, in plot(scalex, scaley, data, *args, **kwargs)
#    2755 @_copy_docstring_and_deprecators(Axes.plot)
#    2756 def plot(*args, scalex=True, scaley=True, data=None, **kwargs):
# -> 2757     return gca().plot(
#    2758         *args, scalex=scalex, scaley=scaley,
#    2759         **({"data": data} if data is not None else {}), **kwargs)
#
# File C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\axes\_axes.py:1634, in Axes.plot(self, scalex, scaley, data, *args, **kwargs)
#    1632 lines = [*self._get_lines(*args, data=data, **kwargs)]
#    1633 for line in lines:
# -> 1634     self.add_line(line)
#    1635 self._request_autoscale_view(scalex=scalex, scaley=scaley)
#    1636 return lines
#
# File C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\axes\_base.py:2283, in _AxesBase.add_line(self, line)
#    2280 if line.get_clip_path() is None:
#    2281     line.set_clip_path(self.patch)
# -> 2283 self._update_line_limits(line)
#    2284 if not line.get_label():
#    2285     line.set_label(f'_child{len(self._children)}')
#
# File C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\axes\_base.py:2306, in _AxesBase._update_line_limits(self, line)
#    2302 def _update_line_limits(self, line):
#    2303     """
#    2304     Figures out the data limit of the given line, updating self.dataLim.
#    2305     """
# -> 2306     path = line.get_path()
#    2307     if path.vertices.size == 0:
#    2308         return
#
# File C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\lines.py:999, in Line2D.get_path(self)
#     997 """Return the `~matplotlib.path.Path` associated with this line."""
#     998 if self._invalidy or self._invalidx:
# --> 999     self.recache()
#    1000 return self._path
#
# File C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\lines.py:652, in Line2D.recache(self, always)
#     650 if always or self._invalidx:
#     651     xconv = self.convert_xunits(self._xorig)
# --> 652     x = _to_unmasked_float_array(xconv).ravel()
#     653 else:
#     654     x = self._x
#
# File C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\cbook\__init__.py:1298, in _to_unmasked_float_array(x)
#    1296     return np.ma.asarray(x, float).filled(np.nan)
#    1297 else:
# -> 1298     return np.asarray(x, float)
#
# TypeError: float() argument must be a string or a number, not 'Period'

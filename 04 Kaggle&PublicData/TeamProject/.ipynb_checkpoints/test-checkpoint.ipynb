# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df_virus = pd.read_excel('./Data/virus.xlsx', header=4)
df_interest = pd.read_csv('./Data/intrest.csv', encoding='euc_kr')
                          
df_price = pd.read_csv('./Data/price.csv', encoding='euc_kr')

# %%
df_virus
# Out:
#                       일자      계(명)   국내발생(명) 해외유입(명)  사망(명)
# 0                  누적(명)  18788056  18748554   39502  24753
# 1    2020-01-20 00:00:00         1         -       1      -
# 2    2020-01-21 00:00:00         0         -       -      -
# 3    2020-01-22 00:00:00         0         -       -      -
# 4    2020-01-23 00:00:00         0         -       -      -
# ..                   ...       ...       ...     ...    ...
# 907  2022-07-14 00:00:00     39186     38850     336     16
# 908  2022-07-15 00:00:00     38882     38621     261     16
# 909  2022-07-16 00:00:00     41310     41023     287     16
# 910  2022-07-17 00:00:00     40342     40037     305     14
# 911  2022-07-18 00:00:00     26299     25980     319     11
#
# [912 rows x 5 columns]

# %%
df_price
# Out:
#   시도별            지출목적별  2019.01  2019.02  2019.03  2019.04  2019.05  2019.06  \
# 0  전국  개인운송장비 연료 및 윤활유  100.686   99.851  101.153  104.908  111.235  112.049
# 1  전국              휘발유   98.056   97.171   98.514  102.576  109.214  110.197
# 2  전국               경유  104.995  104.100  105.715  109.885  115.713  116.215
# 3  전국          자동차용LPG  101.296  100.888  100.755  100.643  106.826  107.785
#
#    2019.07  2019.08  ...  2021.09  2021.10  2021.11  2021.12  2022.01  \
# 0  109.097  109.064  ...   119.61   123.07   129.05   121.61   120.10
# 1  107.729  107.915  ...   118.62   122.06   127.11   118.78   117.52
# 2  113.399  113.334  ...   120.35   124.48   131.08   123.08   121.26
# 3  101.071   99.622  ...   123.93   124.16   134.67   137.56   135.59
#
#    2022.02  2022.03  2022.04  2022.05  2022.06
# 0   125.63   143.29   148.74   149.22   157.47
# 1   123.23   138.99   142.49   141.16   149.39
# 2   128.10   151.40   159.04   163.22   173.11
# ...

# %%
df_price.drop(0, inplace = True)

# %%
df_price
# Out:
#   시도별    지출목적별  2019.01  2019.02  2019.03  2019.04  2019.05  2019.06  2019.07  \
# 1  전국      휘발유   98.056   97.171   98.514  102.576  109.214  110.197  107.729
# 2  전국       경유  104.995  104.100  105.715  109.885  115.713  116.215  113.399
# 3  전국  자동차용LPG  101.296  100.888  100.755  100.643  106.826  107.785  101.071
#
#    2019.08  ...  2021.09  2021.10  2021.11  2021.12  2022.01  2022.02  \
# 1  107.915  ...   118.62   122.06   127.11   118.78   117.52   123.23
# 2  113.334  ...   120.35   124.48   131.08   123.08   121.26   128.10
# 3   99.622  ...   123.93   124.16   134.67   137.56   135.59   132.79
#
#    2022.03  2022.04  2022.05  2022.06
# 1   138.99   142.49   141.16   149.39
# 2   151.40   159.04   163.22   173.11
# 3   136.95   147.15   143.44   143.34
#
# [3 rows x 44 columns]

# %%
df_price.set_index('지출목적별', inplace=True)

# %%
df_price.drop('시도별', axis=1, inplace = True)

# %%
df_price
# Out:
#          2019.01  2019.02  2019.03  2019.04  2019.05  2019.06  2019.07  \
# 지출목적별
# 휘발유       98.056   97.171   98.514  102.576  109.214  110.197  107.729
# 경유       104.995  104.100  105.715  109.885  115.713  116.215  113.399
# 자동차용LPG  101.296  100.888  100.755  100.643  106.826  107.785  101.071
#
#          2019.08  2019.09  2019.10  ...  2021.09  2021.10  2021.11  2021.12  \
# 지출목적별                               ...
# 휘발유      107.915  110.393  111.540  ...   118.62   122.06   127.11   118.78
# 경유       113.334  115.560  116.510  ...   120.35   124.48   131.08   123.08
# 자동차용LPG   99.622   99.092   99.041  ...   123.93   124.16   134.67   137.56
#
#          2022.01  2022.02  2022.03  2022.04  2022.05  2022.06
# 지출목적별
# 휘발유       117.52   123.23   138.99   142.49   141.16   149.39
# 경유        121.26   128.10   151.40   159.04   163.22   173.11
# 자동차용LPG   135.59   132.79   136.95   147.15   143.44   143.34
#
# [3 rows x 42 columns]

# %%
plt.plot(df_price)
plt.show()
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\IPython\core\pylabtools.py:151: UserWarning: Glyph 55064 (\N{HANGUL SYLLABLE HWI}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\ProgramData\Anaconda3\lib\site-packages\IPython\core\pylabtools.py:151: UserWarning: Glyph 48156 (\N{HANGUL SYLLABLE BAL}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\ProgramData\Anaconda3\lib\site-packages\IPython\core\pylabtools.py:151: UserWarning: Glyph 50976 (\N{HANGUL SYLLABLE YU}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\ProgramData\Anaconda3\lib\site-packages\IPython\core\pylabtools.py:151: UserWarning: Glyph 44221 (\N{HANGUL SYLLABLE GYEONG}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\ProgramData\Anaconda3\lib\site-packages\IPython\core\pylabtools.py:151: UserWarning: Glyph 51088 (\N{HANGUL SYLLABLE JA}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# ...
